# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Arial"

# %%
from matplotlib import pyplot as plt 
import seaborn as sns 
current_palette = sns.color_palette() 
sns.palplot(sns.color_palette("colorblind")) 
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
scenario = ['Moderate climate \nchange, \nHigh urbanization',
            'Moderate climate \nchange, \nLow urbanization',
            'Extreme climate \nchange, \nHigh urbanization',
            'Extreme climate \nchange, \nLow urbanization']

sim = ['Business-\nas-usual','Price \nregulation','Infrastructure \nmanagement',
       'Agricultural-\nto-urban','Enhanced \npiped supply','Comprehensive \naction',]
sim2=np.repeat(sim,4)

# %%
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.legend_handler import HandlerTuple
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

# %%
basepath = r"/scratch/users/awan005/bhima_mas_code_publication"
path = basepath + r"/outputs/data_processed/human_wellbeing_metrics" +"/"
use = pd.read_csv(path + r"use09182024.csv")
vul = pd.read_csv(path + r"vul09182024.csv")
dur = pd.read_csv(path + r"stress09182024.csv")
cost = pd.read_csv(path + r"cost09182024.csv")
gin = pd.read_csv(path + r"gini09182024.csv")

# %%
mean_poor,mean_mid,mean_rich,max_poor,max_mid,max_rich,min_poor,min_mid,min_rich={},{},{},{},{},{},{},{},{}
moderate_high_poor,moderate_low_poor,extreme_high_poor,extreme_low_poor={},{},{},{}
moderate_high_mid,moderate_low_mid,extreme_high_mid,extreme_low_mid={},{},{},{}
moderate_high_rich,moderate_low_rich,extreme_high_rich,extreme_low_rich={},{},{},{}
count=0

# %%
# Data for water use
moderate_high_poor[0]=use.iloc[11,1+count*3:4+count*3]
moderate_low_poor[0]=use.iloc[11,1+(1+count)*3:4+(1+count)*3]
extreme_high_poor[0]=use.iloc[11,1+(2+count)*3:4+(2+count)*3]
extreme_low_poor[0]=use.iloc[11,1+(3+count)*3:4+(3+count)*3]

moderate_high_mid[0]=use.iloc[10,1+count*3:4+count*3]
moderate_low_mid[0]=use.iloc[10,1+(1+count)*3:4+(1+count)*3]
extreme_high_mid[0]=use.iloc[10,1+(2+count)*3:4+(2+count)*3]
extreme_low_mid[0]=use.iloc[10,1+(3+count)*3:4+(3+count)*3]

moderate_high_rich[0]=use.iloc[9,1+count*3:4+count*3]
moderate_low_rich[0]=use.iloc[9,1+(1+count)*3:4+(1+count)*3]
extreme_high_rich[0]=use.iloc[9,1+(2+count)*3:4+(2+count)*3]
extreme_low_rich[0]=use.iloc[9,1+(3+count)*3:4+(3+count)*3]

# mean, max and min
mean_poor[0] = np.mean(np.array([use.iloc[11, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
mean_mid[0] = np.mean(np.array([use.iloc[10, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
mean_rich[0] = np.mean(np.array([use.iloc[9, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

max_poor[0] = np.max(np.array([use.iloc[11, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
max_mid[0] = np.max(np.array([use.iloc[10, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
max_rich[0] = np.max(np.array([use.iloc[9, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

min_poor[0] = np.min(np.array([use.iloc[11, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
min_mid[0] = np.min(np.array([use.iloc[10, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
min_rich[0] = np.min(np.array([use.iloc[9, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

# %%
# Data for gini
moderate_high_rich[1]=gin.iloc[0,1+count*3:4+count*3]
moderate_low_rich[1]=gin.iloc[0,1+(1+count)*3:4+(1+count)*3]
extreme_high_rich[1]=gin.iloc[0,1+(2+count)*3:4+(2+count)*3]
extreme_low_rich[1]=gin.iloc[0,1+(3+count)*3:4+(3+count)*3]

# mean, max and min
mean_rich[1] = np.mean(np.array([gin.iloc[0, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
max_rich[1] = np.max(np.array([gin.iloc[0, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
min_rich[1] = np.min(np.array([gin.iloc[0, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

# %%
count=0
count1=1
count2=2
count3=3

# Data for affordability
moderate_high_poor[2]=100*(cost.iloc[2,1+count*3:4+count*3]+cost.iloc[5,1+count*3:4+count*3]+cost.iloc[8,1+count*3:4+count*3]+cost.iloc[11,1+count*3:4+count*3])
moderate_low_poor[2]=100*(cost.iloc[2,1+count1*3:4+count1*3]+cost.iloc[5,1+count1*3:4+count1*3]+cost.iloc[8,1+count1*3:4+count1*3]+cost.iloc[11,1+count1*3:4+count1*3])
extreme_high_poor[2]=100*(cost.iloc[2,1+count2*3:4+count2*3]+cost.iloc[5,1+count2*3:4+count2*3]+cost.iloc[8,1+count2*3:4+count2*3]+cost.iloc[11,1+count2*3:4+count2*3])
extreme_low_poor[2]=100*(cost.iloc[2,1+count3*3:4+count3*3]+cost.iloc[5,1+count3*3:4+count3*3]+cost.iloc[8,1+count3*3:4+count3*3]+cost.iloc[11,1+count3*3:4+count3*3])

moderate_high_mid[2]=100*(cost.iloc[1,1+count*3:4+count*3]+cost.iloc[4,1+count*3:4+count*3]+cost.iloc[7,1+count*3:4+count*3]+cost.iloc[10,1+count*3:4+count*3])
moderate_low_mid[2]=100*(cost.iloc[1,1+count1*3:4+count1*3]+cost.iloc[4,1+count1*3:4+count1*3]+cost.iloc[7,1+count1*3:4+count1*3]+cost.iloc[10,1+count1*3:4+count1*3])
extreme_high_mid[2]=100*(cost.iloc[1,1+count2*3:4+count2*3]+cost.iloc[4,1+count2*3:4+count2*3]+cost.iloc[7,1+count2*3:4+count2*3]+cost.iloc[10,1+count2*3:4+count2*3])
extreme_low_mid[2]=100*(cost.iloc[1,1+count3*3:4+count3*3]+cost.iloc[4,1+count3*3:4+count3*3]+cost.iloc[7,1+count3*3:4+count3*3]+cost.iloc[10,1+count3*3:4+count3*3])

moderate_high_rich[2]=100*(cost.iloc[0,1+count*3:4+count*3]+cost.iloc[3,1+count*3:4+count*3]+cost.iloc[6,1+count*3:4+count*3]+cost.iloc[9,1+count*3:4+count*3])
moderate_low_rich[2]=100*(cost.iloc[0,1+count1*3:4+count1*3]+cost.iloc[3,1+count1*3:4+count1*3]+cost.iloc[6,1+count1*3:4+count1*3]+cost.iloc[9,1+count1*3:4+count1*3])
extreme_high_rich[2]=100*(cost.iloc[0,1+count2*3:4+count2*3]+cost.iloc[3,1+count2*3:4+count2*3]+cost.iloc[6,1+count2*3:4+count2*3]+cost.iloc[9,1+count2*3:4+count2*3])
extreme_low_rich[2]=100*(cost.iloc[0,1+count3*3:4+count3*3]+cost.iloc[3,1+count3*3:4+count3*3]+cost.iloc[6,1+count3*3:4+count3*3]+cost.iloc[9,1+count3*3:4+count3*3])


# mean, max and min
mean_poor[2] = 100*np.mean(np.array([(cost.iloc[2,1+n*3:4+n*3]+cost.iloc[5,1+n*3:4+n*3]+cost.iloc[8,1+n*3:4+n*3]+cost.iloc[11,1+n*3:4+n*3]).tolist() for n in range(4)]),axis=0)
mean_mid[2] = 100*np.mean(np.array([(cost.iloc[1,1+n*3:4+n*3]+cost.iloc[4,1+n*3:4+n*3]+cost.iloc[7,1+n*3:4+n*3]+cost.iloc[10,1+n*3:4+n*3]).tolist() for n in range(4)]),axis=0)
mean_rich[2] = 100*np.mean(np.array([(cost.iloc[0,1+n*3:4+n*3]+cost.iloc[3,1+n*3:4+n*3]+cost.iloc[6,1+n*3:4+n*3]+cost.iloc[9,1+n*3:4+n*3]).tolist() for n in range(4)]),axis=0)

max_poor[2] = 100*np.max(np.array([(cost.iloc[2,1+n*3:4+n*3]+cost.iloc[5,1+n*3:4+n*3]+cost.iloc[8,1+n*3:4+n*3]+cost.iloc[11,1+n*3:4+n*3]).tolist() for n in range(4)]),axis=0)
max_mid[2] = 100*np.max(np.array([(cost.iloc[1,1+n*3:4+n*3]+cost.iloc[4,1+n*3:4+n*3]+cost.iloc[7,1+n*3:4+n*3]+cost.iloc[10,1+n*3:4+n*3]).tolist() for n in range(4)]),axis=0)
max_rich[2] = 100*np.max(np.array([(cost.iloc[0,1+n*3:4+n*3]+cost.iloc[3,1+n*3:4+n*3]+cost.iloc[6,1+n*3:4+n*3]+cost.iloc[9,1+n*3:4+n*3]).tolist() for n in range(4)]),axis=0)

min_poor[2] = 100*np.min(np.array([(cost.iloc[2,1+n*3:4+n*3]+cost.iloc[5,1+n*3:4+n*3]+cost.iloc[8,1+n*3:4+n*3]+cost.iloc[11,1+n*3:4+n*3]).tolist() for n in range(4)]),axis=0)
min_mid[2] = 100*np.min(np.array([(cost.iloc[1,1+n*3:4+n*3]+cost.iloc[4,1+n*3:4+n*3]+cost.iloc[7,1+n*3:4+n*3]+cost.iloc[10,1+n*3:4+n*3]).tolist() for n in range(4)]),axis=0)
min_rich[2] = 100*np.min(np.array([(cost.iloc[0,1+n*3:4+n*3]+cost.iloc[3,1+n*3:4+n*3]+cost.iloc[6,1+n*3:4+n*3]+cost.iloc[9,1+n*3:4+n*3]).tolist() for n in range(4)]),axis=0)

# %%
# Data for vulnerability
moderate_high_poor[3]=vul.iloc[2,1+count*3:4+count*3]
moderate_low_poor[3]=vul.iloc[2,1+(1+count)*3:4+(1+count)*3]
extreme_high_poor[3]=vul.iloc[2,1+(2+count)*3:4+(2+count)*3]
extreme_low_poor[3]=vul.iloc[2,1+(3+count)*3:4+(3+count)*3]

moderate_high_mid[3]=vul.iloc[1,1+count*3:4+count*3]
moderate_low_mid[3]=vul.iloc[1,1+(1+count)*3:4+(1+count)*3]
extreme_high_mid[3]=vul.iloc[1,1+(2+count)*3:4+(2+count)*3]
extreme_low_mid[3]=vul.iloc[1,1+(3+count)*3:4+(3+count)*3]

moderate_high_rich[3]=vul.iloc[0,1+count*3:4+count*3]
moderate_low_rich[3]=vul.iloc[0,1+(1+count)*3:4+(1+count)*3]
extreme_high_rich[3]=vul.iloc[0,1+(2+count)*3:4+(2+count)*3]
extreme_low_rich[3]=vul.iloc[0,1+(3+count)*3:4+(3+count)*3]

# mean, max and min
mean_poor[3] = np.mean(np.array([vul.iloc[2, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
mean_mid[3] = np.mean(np.array([vul.iloc[1, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
mean_rich[3] = np.mean(np.array([vul.iloc[0, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

max_poor[3] = np.max(np.array([vul.iloc[2, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
max_mid[3] = np.max(np.array([vul.iloc[1, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
max_rich[3] = np.max(np.array([vul.iloc[0, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

min_poor[3] = np.min(np.array([vul.iloc[2, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
min_mid[3] = np.min(np.array([vul.iloc[1, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
min_rich[3] = np.min(np.array([vul.iloc[0, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

# %%
# Data for shortage duration
moderate_high_poor[4]=dur.iloc[2,1+count*3:4+count*3]
moderate_low_poor[4]=dur.iloc[2,1+(1+count)*3:4+(1+count)*3]
extreme_high_poor[4]=dur.iloc[2,1+(2+count)*3:4+(2+count)*3]
extreme_low_poor[4]=dur.iloc[2,1+(3+count)*3:4+(3+count)*3]

moderate_high_mid[4]=dur.iloc[1,1+count*3:4+count*3]
moderate_low_mid[4]=dur.iloc[1,1+(1+count)*3:4+(1+count)*3]
extreme_high_mid[4]=dur.iloc[1,1+(2+count)*3:4+(2+count)*3]
extreme_low_mid[4]=dur.iloc[1,1+(3+count)*3:4+(3+count)*3]

moderate_high_rich[4]=dur.iloc[0,1+count*3:4+count*3]
moderate_low_rich[4]=dur.iloc[0,1+(1+count)*3:4+(1+count)*3]
extreme_high_rich[4]=dur.iloc[0,1+(2+count)*3:4+(2+count)*3]
extreme_low_rich[4]=dur.iloc[0,1+(3+count)*3:4+(3+count)*3]

# mean, max and min
mean_poor[4] = np.mean(np.array([dur.iloc[2, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
mean_mid[4] = np.mean(np.array([dur.iloc[1, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
mean_rich[4] = np.mean(np.array([dur.iloc[0, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

max_poor[4] = np.max(np.array([dur.iloc[2, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
max_mid[4] = np.max(np.array([dur.iloc[1, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
max_rich[4] = np.max(np.array([dur.iloc[0, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

min_poor[4] = np.min(np.array([dur.iloc[2, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
min_mid[4] = np.min(np.array([dur.iloc[1, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)
min_rich[4] = np.min(np.array([dur.iloc[0, 1+n*3:4+n*3].tolist() for n in range(4)]),axis=0)

# %%
tit = ['Per capita water use','Inequality','Unaffordability','Vulnerability','Shortage duration']
lab=['Liters\nper capita\nper day',
    'Gini\ncoefficient\nin water\nuse',
    'Percentage\nof income\nspent on\nwater',
    'Percentage\npopulation\nreceiving\nwater\n<40 LPCD',
    'Number of\nconsecutive\nvulnerable\nmonths',]

# %%
# %matplotlib inline

# %%
fig = plt.figure(figsize=(7,9),dpi=1000)

# Manually specify axes positions [left, bottom, width, height]
ax0 = fig.add_axes([0.15, 0.79-0.1, 0.35, 0.27])   # Top-left
ax1 = fig.add_axes([0.15, 0.47-0.1, 0.35, 0.27])   # Top-left
ax2 = fig.add_axes([0.64, 0.47-0.1, 0.35, 0.27])   # Top-right
ax3 = fig.add_axes([0.15, 0.15-0.1, 0.35, 0.27])   # Bottom-left
ax4 = fig.add_axes([0.64, 0.15-0.1, 0.35, 0.27])   # Bottom-right

year = range(0,4,1)
year_intervention = range(2,4,1)
ind=0.27
wid=0.25
categories = ['Avg','Yr1','Yr2']

cc=0


# Set up bar positions
x = np.arange(3)
width = 0.25
markers = ['^',      # circle
          'v',      # square
          'x',      # star
          'o']      # triangle up
sizes =[8,8]
num=['(a)','(b)','(c)','(d)','(e)']

colors = [ 'none', 'none','none','#333333', ]  # Color for each vertical position
high_income = '#1b9e77'    # Teal
mid_income = '#4393c3'     # Purple
low_income = '#d95f02'     # Orange
gini_color= '#f1a226'


colors = [ 'none','none','#333333',  '#333333']  # Color for each vertical position
high_income = '#1b9e77'    # Teal
mid_income = '#4393c3'     # Purple
low_income = '#d95f02'     # Orange

ax0.axhline(40,color='red',linestyle='--',zorder=1,linewidth=1)
ax2.axhline(5,color='red', linestyle='--',linewidth=1)

ax_list=[0,2,3,4]
for ax in [ax0,ax2,ax3,ax4]:
    # Plot Avg Year、
    c=ax_list[cc]
    avg_bars = ax.bar(x - width/2, min_poor[c], width*0.95, 
                     color=low_income,zorder=0 )
    err_bars = ax.bar(x - width/2, max_poor[c]-min_poor[c], width*0.95, bottom=min_poor[c],
                     color=low_income,alpha=0.3,zorder=0 )
    u=0
    for bar in avg_bars:

        height = bar.get_height()
        x_pos = bar.get_x()
        ax.plot([x_pos, x_pos + width*0.95], [moderate_low_poor[c][u], moderate_low_poor[c][u]],
               'm-', linewidth=1,alpha=0.6, zorder=2)
        ax.plot([x_pos, x_pos + width*0.95], [extreme_high_poor[c][u], extreme_high_poor[c][u]], 
                color='black', linewidth=1,alpha=0.6, zorder=2)
        u+=1

    data = np.array([moderate_high_poor[c].tolist(),extreme_low_poor[c].tolist()]).T.tolist()                              
    for i, y in enumerate(data):
        for j, (value, marker,ss,color) in enumerate(zip(y, markers,sizes,colors)):
            if ax==ax0 or (ax==ax2 and i==0):
                ax.scatter([i-width/2-(j-0.5)/15], value, 
                         marker=marker,
                         facecolor=color,
                         edgecolor='#333333',
                         alpha=0.7,
                         s=ss,zorder=3)
            else:
                ax.scatter([i-width/2], value, 
                         marker=marker,
                         facecolor=color,
                         edgecolor='#333333',
                         alpha=0.7,
                         s=ss,zorder=3)

    # Plot Year 1 
    yr1_bars = ax.bar(x + width/2, min_mid[c], width*0.95, 
                     color=mid_income,zorder=0 )
    err1_bars = ax.bar(x + width/2, max_mid[c]-min_mid[c], width*0.95, bottom=min_mid[c],
                     color=mid_income,alpha=0.2,zorder=0 )

    u=0
    for bar in yr1_bars:

        height = bar.get_height()
        x_pos = bar.get_x()
        ax.plot([x_pos, x_pos + width*0.95], [moderate_low_mid[c][u], moderate_low_mid[c][u]],
               'm-', linewidth=1,alpha=0.6, zorder=2)
        ax.plot([x_pos, x_pos + width*0.95], [extreme_high_mid[c][u], extreme_high_mid[c][u]], 
                color='black', linewidth=1,alpha=0.6, zorder=2)
        u+=1

    data = np.array([moderate_high_mid[c].tolist(),extreme_low_mid[c].tolist()]).T.tolist()                              
    for i, y in enumerate(data):
        for j, (value, marker,ss,color) in enumerate(zip(y, markers,sizes,colors)):
            if i == 0 and ax==ax2:
                ax.scatter([i+width/2-(j-0.5)/15], value, 
                 marker=marker,
                 facecolor=color,
                 edgecolor='#333333', 
                     alpha=0.7,
                     s=ss,zorder=3)    
            else:
                ax.scatter([i+width/2], value, 
                 marker=marker,
                 facecolor=color,
                 edgecolor='#333333', 
                     alpha=0.7,
                     s=ss,zorder=3)  


    # Plot Year 2 
    yr2_bars = ax.bar(x + width*3/2, min_rich[c], width*0.95, 
                     color=high_income,zorder=0 )
    err2_bars = ax.bar(x + width*3/2, max_rich[c]-min_rich[c], width*0.95, bottom=min_rich[c],
                     color=high_income,alpha=0.2,zorder=0 )

    u=0
    for bar in yr2_bars:

        height = bar.get_height()
        x_pos = bar.get_x()
        ax.plot([x_pos, x_pos + width*0.95], [moderate_low_rich[c][u], moderate_low_rich[c][u]],
                'm-', linewidth=1,alpha=0.6, zorder=2)
        ax.plot([x_pos, x_pos + width*0.95], [extreme_high_rich[c][u], extreme_high_rich[c][u]], 
                color='black', linewidth=1,alpha=0.6, zorder=2)
        u+=1


    data = np.array([moderate_high_rich[c].tolist(),extreme_low_rich[c].tolist()]).T.tolist()                              
    for i, y in enumerate(data):
        for j, (value, marker,ss,color) in enumerate(zip(y, markers,sizes,colors)):
            if (i == 0 and (ax==ax3 or ax==ax4 or ax==ax2)) or (i==1 and ax==ax0):
                ax.scatter([i+width*3/2-(j-0.5)/15], value, 
                 marker=marker,
                 facecolor=color,
                 edgecolor='#333333', 
                     alpha=0.7,
                     s=ss,zorder=3)    
            else:
                ax.scatter([i+width*3/2], value, 
                     marker=marker,
                     facecolor=color,
                     edgecolor='#333333', 
                     alpha=0.7,
                     s=ss,zorder=3)    
    cc+=1
    

for ax in [ax1]:

    width=0.25
    mean_values_rich = mean_rich[1]                                         # mean scenario
    yerr_low_rich = [a-b for a, b in zip(mean_rich[1],min_rich[1])]            # difference to min scenario
    yerr_high_rich = [a-b for a, b in zip(max_rich[1],mean_rich[1])]           # difference to max scenario  


    # Plot Year 2 
    yr2_bars = ax.bar(x + width*1/2, min_rich[1], width*0.95,
                     color=sns.color_palette("colorblind")[1],alpha=1,zorder=0 )
    err2_bars = ax.bar(x + width*1/2, max_rich[1]-min_rich[1], width*0.95,bottom=min_rich[1], 
                     color=sns.color_palette("colorblind")[1],alpha=0.3,zorder=0 )
    u=0
    for bar in yr2_bars:

        height = bar.get_height()
        x_pos = bar.get_x()
        ax.plot([x_pos, x_pos + width*0.95], [moderate_low_rich[1][u], moderate_low_rich[1][u]], 
                'm-', linewidth=1,alpha=0.6, zorder=2)
        ax.plot([x_pos, x_pos + width*0.95], [extreme_high_rich[1][u], extreme_high_rich[1][u]], 
                color='black', linewidth=1,alpha=0.6, zorder=2)
        u+=1

    data = np.array([moderate_high_rich[1].tolist(),extreme_low_rich[1].tolist()]).T.tolist()                              
    for i, y in enumerate(data):
        for j, (value, marker,ss,color) in enumerate(zip(y, markers,sizes,colors)):
            ax.scatter([i+width*1/2], value, 
                     marker=marker,
                     facecolor=color,
                     edgecolor='#333333', 
                     alpha=0.7,
                     s=ss,zorder=3)    
            
n =0
for ax in [ax0,ax1,ax2,ax3,ax4]:
    ax.set_ylabel(lab[n], rotation=0,labelpad=25,y=0.4)
    ax.set_title(tit[n],fontsize=11)
    ax0.set_ylim(0, 160)
    ax1.set_ylim(0,0.6)
    ax3.set_ylim(0, 90)
    ax4.set_ylim(0, 10)
    ax2.set_ylim(0, 20)
    ax2.set_yticks(np.arange(0,21,step=5))
    ax.set_xticks([m+width/2 for m in x])
    ax.set_xticklabels(categories, rotation=0, ha='center')
    ax.tick_params(axis='x', color='white')
    ax.text(-0.1, 1.05, num[n], transform=ax.transAxes)


    for item in ([ ax.xaxis.label, ax.yaxis.label] +
                 ax.get_xticklabels() + ax.get_yticklabels()):
        item.set_fontsize(8) 

    # Add horizontal grid
    ax.yaxis.grid(True, linestyle='--', alpha=0.7)
    ax.set_axisbelow(True)
    n+=1

    
    
# Create a separate legend axes below the main axes
legend_ax = fig.add_axes([0.6, 0.69, 0.45, 0.1])
legend_ax.axis('off')

# Add legend
legend_elements = [
    plt.Rectangle((0,0),1,1, facecolor=low_income, label='Low-income (bottom 10%)'),
    plt.Rectangle((0,0),1,1, facecolor=mid_income, label='Middle-income (middle 80%)'),
    plt.Rectangle((0,0),1,1, facecolor=high_income, label='High-income (top 10%)'),
    plt.Rectangle((0,0),1,1, facecolor='none', label='')
]

# # Combine and display legend
# legend = legend_ax.legend(handles=legend_elements + top + scatters + bt,
#                          loc='best', 
#                          ncol=2,
#                          fontsize=8,
#                          frameon=True)

# First legend - income groups
legend1 = legend_ax.legend(handles=legend_elements,
                           bbox_to_anchor=(-0.04,2), 
                          loc='upper left',
                          ncol=1,
                          fontsize=8,
                          frameon=False)

# Add the first legend manually
legend_ax.add_artist(legend1)
# Create three separate legends
legend_ax.text(-0.1, 6, 'Scenario sets:', fontsize=9)
legend_ax.text(-0.1, 11, 'Income groups:', fontsize=9)
legend_ax.text(-0.1, 13, 'Legend', fontsize=10,weight='bold')
# Create example bar for the legend with annotations
bar_width = 0.15
bar_height = 5
bar_x=0
bar_y = 0.02

legend_ax.set_xlim(0, 2.5)

# Draw example bar
rect_bottom = mpatches.Rectangle((bar_x, bar_y), bar_width, bar_height, 
                                 facecolor=mid_income, alpha=0.2)

legend_ax.add_patch(rect_bottom)


# Add horizontal lines for min/max
legend_ax.plot([bar_x, bar_x+bar_width], [bar_y, bar_y], 'k-', linewidth=1, alpha=0.6)
legend_ax.plot([bar_x, bar_x+bar_width], [bar_y+bar_height, bar_y+bar_height], 'm-', linewidth=1, alpha=0.6)

# Add markers
legend_ax.scatter(bar_x+bar_width/2, bar_y+bar_height-1.7, marker='v', 
                 facecolor='none', edgecolor='#333333', s=30,alpha=0.8)
legend_ax.scatter(bar_x+bar_width/2, bar_y+1.7, marker='^', 
                 facecolor='none', edgecolor='#333333', s=30,alpha=0.8)

# Add arrows and labels
arrowprops = dict(facecolor='black', shrink=0.05, width=0.1, headwidth=2, alpha=0.5,headlength=4)

# Arrow to top of bar
legend_ax.annotate('Moderate Climate Change, Low Urbanization',
                  xy=(bar_x+bar_width*1.1, bar_y+bar_height), xytext=(0.3, bar_y+bar_height),
                  arrowprops=arrowprops, fontsize=8, ha='left', va='center')

# Arrow to bottom of bar
legend_ax.annotate('Extreme Climate Change, High Urbanization',
                  xy=(bar_x+bar_width*1.1, bar_y), xytext=(0.3, bar_y),
                  arrowprops=arrowprops, fontsize=8, ha='left', va='center')

# Arrow to up triangle
legend_ax.annotate('Extreme Climate Change, Low Urbanization',
                  xy=(bar_x+bar_width*1.1, bar_y+bar_height-1.7), xytext=(0.3, bar_y+bar_height-1.7),
                  arrowprops=arrowprops, fontsize=8, ha='left', va='center')

# Arrow to down triangle
legend_ax.annotate('Moderate Climate Change, High Urbanization',
                  xy=(bar_x+bar_width*1.1, bar_y+1.7), xytext=(0.3, bar_y+1.7),
                  arrowprops=arrowprops, fontsize=8, ha='left', va='center')

# plt.savefig('scenario_pdf.pdf', bbox_inches=None)
# Out:
# Text(0.3, 1.72, 'Moderate Climate Change, High Urbanization')
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
